# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#  Постройте на одном графике две кривые y(x) для функции двух переменных y(k,x)=cos(k∙x), взяв для одной кривой значение k=1, а для другой – любое другое k, не равное 1.

# %%
x=np.linspace(-5, 5, 100)
y = np.cos(k1*x)
k1=1
k2=2
plt.xlabel("x")
plt.ylabel("y(x)")
plt.plot(x,y)
plt.plot(x, np.cos(k2*x))

# %%
x=np.linspace(-5, 5, 100)
y2 = np.cos(k1*x)
y1 = np.cos(k2*x)
k1=1
k2=2

fig, ax = plt.subplots(figsize=(8, 6))

ax.set_title("Графики зависимостей: y1=cos(k2*x), y2=cos(k1*x)", fontsize=16)
ax.set_xlabel("x", fontsize=14)        
ax.set_ylabel("y1, y2", fontsize=14)
ax.grid(which="major", linewidth=1.2)
ax.grid(which="minor", color="gray", linewidth=0.5)
ax.plot(x, y1, c="red", label="y1=cos(k2*x)")
ax.plot(x, y2, label="y2=cos(k1*x)")
ax.legend(loc='center', fontsize =15)

fig.set_figwidth(12)
fig.set_figheight(12)

plt.show()
